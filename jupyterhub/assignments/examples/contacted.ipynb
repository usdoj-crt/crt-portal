# %%
# %load_ext sql
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False
# %config SqlMagic.displaylimit = 500
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %%sql --save first_contacts --no-execute
#
# SELECT target_object_id, first_description, timestamp
# FROM (
#     SELECT
#     target_object_id,
#     timestamp,
#     first_value(description) OVER (PARTITION BY target_object_id ORDER BY timestamp) first_description
#     FROM actstream_action
#     WHERE verb='Contacted complainant:'
# ) first_descriptions
# WHERE first_description NOT LIKE '%CRT Auto response%'
# GROUP BY 1, 2, 3
# Out:
# There's a new jupysql version available (0.7.9), you're running 0.7.8. To upgrade: pip install jupysql --upgrade
# Skipping execution...

# %%
# %%sql --save letter_kinds --no-execute
#
# WITH languages (name) as (
#     values
#         ('Spanish'),
#         ('English'),
#         ('Chinese Traditional'),
#         ('Chinese Simplified'),
#         ('Vietnamese'),
#         ('Korean'),
#         ('Tagalog')
# )
# SELECT
#     title,
#     COALESCE((SELECT
#         TRIM(REPLACE(title, '(' || languages.name || ')', ''))
#         FROM languages
#         WHERE title LIKE '%' || languages.name || '%'
#         LIMIT 1
#     ), title) AS clean_title,
#     language,
#     referral_contact_id IS NOT NULL AS is_referral,
#     title LIKE '%Constant Writer%' AS is_constant_writer,
#     title LIKE '%No Capacity%' AS is_no_capacity
# FROM cts_forms_responsetemplate
# Out:
# Skipping execution...

# %%
# %%sql --save day_buckets --no-execute
#
# WITH day_buckets (position, low, high, name) AS (
#     VALUES
#         (0, INTERVAL '0 days', INTERVAL '1 day', 'Less than a day'),
#         (1, INTERVAL '1 day', INTERVAL '2 days', 'Two days'),
#         (2, INTERVAL '2 days', '3 days', 'Three days'),
#         (3, INTERVAL '3 days', '4 days', 'Four days'),
#         (4, INTERVAL '4 days', '5 days', 'Five days'),
#         (5, INTERVAL '5 days', '6 days', 'Six days'),
#         (6, INTERVAL '6 days', '7 days', 'One week'),
#         (7, INTERVAL '8 days', '14 days', 'Two Weeks'),
#         (8, INTERVAL '15 days', '31 days', 'One Month'),
#         (9, INTERVAL '31 days', '1000 years', 'More than a Month')
# ) SELECT * FROM day_buckets
# Out:
# Skipping execution...

# %%
# %%sql response_times << --with letter_kinds --with first_contacts --with day_buckets
#
# SELECT
#     day_buckets.position,
#     day_buckets.name time_to_response,
#     COALESCE(letter_kinds.clean_title, first_contacts.first_description) title,
#     letter_kinds.language,
#     letter_kinds.is_referral,
#     letter_kinds.is_constant_writer,
#     letter_kinds.is_no_capacity,
#     COUNT(*) responses_sent
# FROM first_contacts
# LEFT JOIN letter_kinds ON first_description LIKE '%' || letter_kinds.title || '%'
# LEFT JOIN cts_forms_report ON CAST(cts_forms_report.id AS varchar) = target_object_id
# LEFT JOIN day_buckets ON
#     day_buckets.low < first_contacts.timestamp - cts_forms_report.create_date AND
#     day_buckets.high >= first_contacts.timestamp - cts_forms_report.create_date
# GROUP BY 1,2,3,4,5,6,7
# ORDER BY position

# %%
import plotly.express as px
df = response_times.DataFrame()

# %%
language_df = df.groupby(["is_referral", "language", "time_to_response"], as_index=False)['responses_sent'].sum()

fig = px.bar(
    language_df,
    x="time_to_response",
    y="responses_sent",
    color="language",
    facet_col="is_referral",
    category_orders={
        "time_to_response": ["Less than a day", "Two days", "Three days", "Four days", "Five days", "Six days", "One week", "Two Weeks", "One Month", "More than a Month",
],
        "is_referral": [True, False],
        "language": ["en", "es", "zh-hant", "zh-hans", "vi", "ko", "tl"]
    },
    height=700,
)

fig.show()
# Out:
# <div>                            <div id="1c07cd52-7aba-47ef-a82f-47e2aeb17b6b" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1c07cd52-7aba-47ef-a82f-47e2aeb17b6b")) {                    Plotly.newPlot(                        "1c07cd52-7aba-47ef-a82f-47e2aeb17b6b",                        [{"alignmentgroup":"True","hovertemplate":"language=en\u003cbr\u003eis_referral=True\u003cbr\u003etime_to_response=%{x}\u003cbr\u003eresponses_sent=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"en","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"en","offsetgroup":"en","orientation":"v","showlegend":true,"textposition":"auto","x":["Five days","Four days","Less than a day","More than a Month","One Month","One week","Six days","Three days","Two Weeks","Two days"],"xaxis":"x","y":[690,515,495,14826,7780,530,595,575,3155,615],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"language=en\u003cbr\u003eis_referral=False\u003cbr\u003etime_to_response=%{x}\u003cbr\u003eresponses_sent=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"en","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"en","offsetgroup":"en","orientation":"v","showlegend":false,"textposition":"auto","x":["Five days","Four days","Less than a day","More than a Month","One Month","One week","Six days","Three days","Two Weeks","Two days"],"xaxis":"x2","y":[1535,1355,1020,38373,19645,1440,1375,1240,7685,1300],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"language=es\u003cbr\u003eis_referral=True\u003cbr\u003etime_to_response=%{x}\u003cbr\u003eresponses_sent=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"es","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"es","offsetgroup":"es","orientation":"v","showlegend":true,"textposition":"auto","x":["Five days","Four days","Less than a day","More than a Month","One Month","One week","Six days","Three days","Two Weeks","Two days"],"xaxis":"x","y":[105,75,60,2306,1215,80,110,70,490,110],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"language=es\u003cbr\u003eis_referral=False\u003cbr\u003etime_to_response=%{x}\u003cbr\u003eresponses_sent=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"es","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"es","offsetgroup":"es","orientation":"v","showlegend":false,"textposition":"auto","x":["Five days","Four days","Less than a day","More than a Month","One Month","One week","Six days","Three days","Two Weeks","Two days"],"xaxis":"x2","y":[220,175,135,6070,3280,260,220,230,1275,205],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"language=zh-hant\u003cbr\u003eis_referral=True\u003cbr\u003etime_to_response=%{x}\u003cbr\u003eresponses_sent=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"zh-hant","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"zh-hant","offsetgroup":"zh-hant","orientation":"v","showlegend":true,"textposition":"auto","x":["Five days","Four days","Less than a day","More than a Month","One Month","One week","Six days","Three days","Two Weeks","Two days"],"xaxis":"x","y":[115,75,55,2143,1005,50,85,75,430,75],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"language=zh-hant\u003cbr\u003eis_referral=False\u003cbr\u003etime_to_response=%{x}\u003cbr\u003eresponses_sent=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"zh-hant","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"zh-hant","offsetgroup":"zh-hant","orientation":"v","showlegend":false,"textposition":"auto","x":["Five days","Four days","Less than a day","More than a Month","One Month","One week","Six days","Three days","Two Weeks","Two days"],"xaxis":"x2","y":[195,140,150,5031,2515, ...

# %%
title_df = df.loc[df['is_referral'] == False]
title_df = title_df.groupby(["title", "time_to_response"], as_index=False)['responses_sent'].sum()

fig = px.bar(
    title_df,
    x="time_to_response",
    y="responses_sent",
    color="title",
    category_orders={
        "time_to_response": ["Less than a day", "Two days", "Three days", "Four days", "Five days", "Six days", "One week", "Two Weeks", "One Month", "More than a Month",
],
    },
    height=700,
)

fig.show()
# Out:
# <div>                            <div id="ed29b0be-be54-4090-bb89-3ef76d69413b" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ed29b0be-be54-4090-bb89-3ef76d69413b")) {                    Plotly.newPlot(                        "ed29b0be-be54-4090-bb89-3ef76d69413b",                        [{"alignmentgroup":"True","hovertemplate":"title=CRM - R1 Form Letter\u003cbr\u003etime_to_response=%{x}\u003cbr\u003eresponses_sent=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CRM - R1 Form Letter","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"CRM - R1 Form Letter","offsetgroup":"CRM - R1 Form Letter","orientation":"v","showlegend":true,"textposition":"auto","x":["Five days","Four days","Less than a day","More than a Month","One Month","One week","Six days","Three days","Two Weeks","Two days"],"xaxis":"x","y":[225,430,220,7752,3940,215,275,205,1545,265],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"title=CRM - R2 Form Letter\u003cbr\u003etime_to_response=%{x}\u003cbr\u003eresponses_sent=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CRM - R2 Form Letter","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"CRM - R2 Form Letter","offsetgroup":"CRM - R2 Form Letter","orientation":"v","showlegend":true,"textposition":"auto","x":["Five days","Four days","Less than a day","More than a Month","One Month","One week","Six days","Three days","Two Weeks","Two days"],"xaxis":"x","y":[180,140,135,5550,2785,255,150,210,1255,195],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"title=CRM - Referral to FBI\u003cbr\u003etime_to_response=%{x}\u003cbr\u003eresponses_sent=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CRM - Referral to FBI","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"CRM - Referral to FBI","offsetgroup":"CRM - Referral to FBI","orientation":"v","showlegend":true,"textposition":"auto","x":["Five days","Four days","Less than a day","More than a Month","One Month","One week","Six days","Three days","Two Weeks","Two days"],"xaxis":"x","y":[155,75,120,3461,1795,100,145,100,590,145],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"title=CRT - Comments & Opinions\u003cbr\u003etime_to_response=%{x}\u003cbr\u003eresponses_sent=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CRT - Comments & Opinions","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"CRT - Comments & Opinions","offsetgroup":"CRT - Comments & Opinions","orientation":"v","showlegend":true,"textposition":"auto","x":["Five days","Four days","Less than a day","More than a Month","One Month","One week","Six days","Three days","Two Weeks","Two days"],"xaxis":"x","y":[230,110,140,5909,2955,185,180,170,1150,160],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"title=CRT - Constant Writer\u003cbr\u003etime_to_response=%{x}\u003cbr\u003eresponses_sent=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CRT - Constant Writer","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"CRT - Constant Writer","offsetgroup":"CRT - Constant Writer","orientation":"v","showlegend":true,"textposition":"auto","x":["Five days","Four days","Less than a day","More than a Month","One Month","One week","Six days","Three days","Two Weeks","Two days"],"xaxis":"x","y":[260,175,130,6127,2965,215,325,225,1455,230],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"title=CRT - EEOC Referral Letter\u003cbr\u003etime_to_response=%{x}\u003cbr\u003eresponses_sent=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CRT - EEOC Referral Letter","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"CRT - EEOC Referral Letter","offsetgroup":"CRT - EEOC Referral Letter", ...

# %%
title_df = df.loc[df['is_referral'] == True]
title_df = title_df.groupby(["time_to_response", "title", ], as_index=False)['responses_sent'].sum()

fig = px.bar(
    title_df,
    x="time_to_response",
    y="responses_sent",
    color="title",
    category_orders={
        "time_to_response": ["Less than a day", "Two days", "Three days", "Four days", "Five days", "Six days", "One week", "Two Weeks", "One Month", "More than a Month",
],
    },
    height=700,
)

fig.show()
# Out:
# <div>                            <div id="3b65ceb3-8602-474c-abeb-c20ce31f7ed2" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3b65ceb3-8602-474c-abeb-c20ce31f7ed2")) {                    Plotly.newPlot(                        "3b65ceb3-8602-474c-abeb-c20ce31f7ed2",                        [{"alignmentgroup":"True","hovertemplate":"title=CRT - DOT (ACP-Airlines) Referral Form Letter\u003cbr\u003etime_to_response=%{x}\u003cbr\u003eresponses_sent=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CRT - DOT (ACP-Airlines) Referral Form Letter","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"CRT - DOT (ACP-Airlines) Referral Form Letter","offsetgroup":"CRT - DOT (ACP-Airlines) Referral Form Letter","orientation":"v","showlegend":true,"textposition":"auto","x":["Five days","Four days","Less than a day","More than a Month","One Month","One week","Six days","Three days","Two Weeks","Two days"],"xaxis":"x","y":[310,155,130,3896,1925,145,165,180,785,180],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"title=CRT - DOT (FTA-Public Transp.) Referral Form Letter\u003cbr\u003etime_to_response=%{x}\u003cbr\u003eresponses_sent=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CRT - DOT (FTA-Public Transp.) Referral Form Letter","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"CRT - DOT (FTA-Public Transp.) Referral Form Letter","offsetgroup":"CRT - DOT (FTA-Public Transp.) Referral Form Letter","orientation":"v","showlegend":true,"textposition":"auto","x":["Five days","Four days","Less than a day","More than a Month","One Month","One week","Six days","Three days","Two Weeks"],"xaxis":"x","y":[10,30,35,476,290,25,30,40,140],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"title=CRT - DOT (OCR - Other Matters) Referral Form Letter\u003cbr\u003etime_to_response=%{x}\u003cbr\u003eresponses_sent=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CRT - DOT (OCR - Other Matters) Referral Form Letter","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"CRT - DOT (OCR - Other Matters) Referral Form Letter","offsetgroup":"CRT - DOT (OCR - Other Matters) Referral Form Letter","orientation":"v","showlegend":true,"textposition":"auto","x":["Five days","More than a Month","One Month","One week","Three days","Two Weeks","Two days"],"xaxis":"x","y":[5,133,45,5,5,15,10],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"title=CRT - Dept of Ed Referral Form Letter\u003cbr\u003etime_to_response=%{x}\u003cbr\u003eresponses_sent=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CRT - Dept of Ed Referral Form Letter","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"CRT - Dept of Ed Referral Form Letter","offsetgroup":"CRT - Dept of Ed Referral Form Letter","orientation":"v","showlegend":true,"textposition":"auto","x":["Five days","Four days","Less than a day","More than a Month","One Month","One week","Six days","Three days","Two Weeks","Two days"],"xaxis":"x","y":[295,255,190,7227,3995,290,265,260,1540,325],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"title=CRT - EEOC Referral Form Letter\u003cbr\u003etime_to_response=%{x}\u003cbr\u003eresponses_sent=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CRT - EEOC Referral Form Letter","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"CRT - EEOC Referral Form Letter","offsetgroup":"CRT - EEOC Referral Form Letter","orientation":"v","showlegend":true,"textposition":"auto","x":["Five days","Four days","Less than a day","More than a Month","One Month","One week","Six days","Three days","Two Weeks","Two days"],"xaxis":"x","y":[220,180,245,5862,2975,140,220,275,1215,215],"yaxis":"y","type":"bar"},{"alignmen ...
