# %%
from IPython.display import display, HTML

display(HTML(f"""
<div class="crt-portal-card">

<h3>Configured by admins</h3>
<hr/>
<p>
  We can decide who to show this dashboard to
</p>

</div>
"""))
# Out:
# <div class="crt-portal-card">
#
# <h3>Configured by admins</h3>
# <hr/>
# <p>
#   We can decide who to show this dashboard to
# </p>
#
# </div>
