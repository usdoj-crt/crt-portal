# %%
from IPython.display import display, HTML

display(HTML(f"""
<div class="crt-portal-card dark filter-by-section section-ADM">

<h3>Only for ADM</h3>
<hr/>
<p>
  This dashboard should only be shown when ADM is selected
</p>

</div>
"""))
# Out:
# <div class="crt-portal-card dark filter-by-section section-ADM">
#
# <h3>Only for ADM</h3>
# <hr/>
# <p>
#   This dashboard should only be shown when ADM is selected
# </p>
#
# </div>
